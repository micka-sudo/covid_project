# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import" data-toc-modified-id="Import-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import</a></span><ul class="toc-item"><li><span><a href="#load-csv" data-toc-modified-id="load-csv-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>load csv</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Import

# %%
import csv
import json as JSON
from pymongo import MongoClient
import pandas as pd

# %% [markdown]
# ### load csv

# %%
df_csv = pd.read_csv("cov.csv", sep =";")

# %%
df_csv.to_json("cov_json.json")

# %%
json_cov = open('cov_json.json').read()
data = JSON.loads(json_cov)

# %%
data
# Out:
# {'dep,jour,nb,incid_hosp,incid_rea,incid_dc,incid_rad': {'0': '01,2020-03-18,1.0,,,,',
#   '1': '02,2020-03-18,4.0,,,,',
#   '2': '03,2020-03-18,2.0,,,,',
#   '3': '04,2020-03-18,2.0,,,,',
#   '4': '05,2020-03-18,2.0,,,,',
#   '5': '06,2020-03-18,5.0,,,,',
#   '6': '07,2020-03-18,3.0,,,,',
#   '7': '08,2020-03-18,1.0,,,,',
#   '8': '09,2020-03-18,1.0,,,,',
#   '9': '10,2020-03-18,1.0,,,,',
#   '10': '11,2020-03-18,3.0,,,,',
#   '11': '12,2020-03-18,1.0,,,,',
#   '12': '13,2020-03-18,12.0,,,,',
#   '13': '14,2020-03-18,1.0,,,,',
#   '14': '15,2020-03-18,1.0,,,,',
#   '15': '16,2020-03-18,1.0,,,,',
#   '16': '17,2020-03-18,2.0,,,,',
#   '17': '18,2020-03-18,0.0,,,,',
#   '18': '19,2020-03-18,0.0,,,,',
#   '19': '21,2020-03-18,2.0,,,,',
#   '20': '22,2020-03-18,2.0,,,,',
#   '21': '23,2020-03-18,0.0,,,,',
#   '22': '24,2020-03-18,1.0,,,,',
#   '23': '25,2020-03-18,2.0,,,,',
#   '24': '26,2020-03-18,4.0,,,,',
#   '25': '27,2020-03-18,1.0,,,,',
#   '26': '28,2020-03-18,2.0,,,,',
# ...

# %%
client = MongoClient("127.0.0.1", 27017)
db = client["db_test2"]
collection = db['tst']

# %%
collection.insert_one(data)
client.close()
print("fichier importer avec succés")
# Out:
# fichier importer avec succés

# %%
conda activate mongo
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Could not find conda environment: mongo
# You can list all discoverable environments with `conda info --envs`.

# %%
# Out:
# ^C
#
# Note: you may need to restart the kernel to use updated packages.
